# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel(r'D:\31890\Desktop\codefile\Utils\result\a.xlsx',index_col=0)
#  index_col=0 第一行作为index

# %%
# 删除全0列
df.loc[:, (df==0).all(axis=0)] 
df2 = df.loc[:, ~(df==0).all(axis=0)]

df.plot(kind='box', notch=True, grid=True)
plt.show()

df2.to_excel(r'D:\31890\Desktop\codefile\Utils\result\b.xlsx')
